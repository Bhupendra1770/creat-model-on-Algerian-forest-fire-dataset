# %% [markdown]
# # creating model which can predict Fire Weather Index (FWI) in Algerian forest fire dataset

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("updated_algerian_dataset")

# %%
df.drop(df.columns[0],axis=1,inplace=True)

# %%
df.drop([122,123],inplace=True)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0
# 4   5     6  2012          27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5
#
#      Classes    forest
# 0  not fire          1
# 1  not fire          1
# 2  not fire          1
# 3  not fire          1
# 4  not fire          1

# %%
#we are droping some feature because these feature may not helpfull to our prediction.

df.drop(['day','month','year','Classes  '],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 0 to 244
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  243 non-null    object
#  1    RH          243 non-null    object
#  2    Ws          243 non-null    object
#  3   Rain         243 non-null    object
#  4   FFMC         243 non-null    object
#  5   DMC          243 non-null    object
#  6   DC           243 non-null    object
#  7   ISI          243 non-null    object
#  8   BUI          243 non-null    object
#  9   FWI          243 non-null    object
#  10  forest       243 non-null    int64
# dtypes: int64(1), object(10)
# memory usage: 22.8+ KB

# %%
#we have to convert these feature to int or float so we can perform mathematical operation on that dataset

# %%
df.columns
# Out:
# Index(['Temperature', ' RH', ' Ws', 'Rain ', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI',
#        'FWI', 'forest'],
#       dtype='object')

# %%
df.sample(5)
# Out:
#     Temperature  RH  Ws Rain   FFMC   DMC     DC  ISI   BUI   FWI  forest
# 79           35  62  19   0.0  89.4  23.2  120.9  9.7  31.3  17.2       1
# 234          29  41   8   0.1  83.9  24.9   86.0  2.7  28.9   5.6       0
# 46           29  70  14   0.0  82.8   9.4   34.1  3.2  11.1   3.6       1
# 126          29  80  14   2.0  48.7   2.2    7.6  0.3   2.6   0.1       0
# 124          32  71  12   0.7  57.1   2.5    8.2  0.6   2.8   0.2       0

# %%
#converting these three feature to int
df[['Temperature', ' RH', ' Ws']]=df[['Temperature', ' RH', ' Ws']].astype('int')

# %%
#convert these seven feature to float
df[['Rain ', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI','FWI']]=df[['Rain ', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI','FWI']].astype('float')

# %%
#we converted our columns datatype succesfully
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 0 to 244
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  243 non-null    int32
#  1    RH          243 non-null    int32
#  2    Ws          243 non-null    int32
#  3   Rain         243 non-null    float64
#  4   FFMC         243 non-null    float64
#  5   DMC          243 non-null    float64
#  6   DC           243 non-null    float64
#  7   ISI          243 non-null    float64
#  8   BUI          243 non-null    float64
#  9   FWI          243 non-null    float64
#  10  forest       243 non-null    int64
# dtypes: float64(7), int32(3), int64(1)
# memory usage: 19.9 KB

# %%
df.shape
# Out:
# (243, 11)

# %%
#checking for null values
df.isnull().sum()
# Out:
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# forest         0
# dtype: int64

# %%
df.describe()
# Out:
#        Temperature          RH          Ws       Rain         FFMC  \
# count   243.000000  243.000000  243.000000  243.000000  243.000000
# mean     32.205761   61.930041   15.506173    0.762963   77.931276
# std       3.603093   14.914330    2.815791    2.003207   14.350967
# min      22.000000   21.000000    6.000000    0.000000   28.600000
# 25%      30.000000   52.000000   14.000000    0.000000   72.450000
# 50%      32.000000   63.000000   15.000000    0.000000   83.700000
# 75%      35.000000   73.500000   17.000000    0.500000   88.300000
# max      42.000000   90.000000   29.000000   16.800000   96.000000
#
#               DMC          DC         ISI        BUI         FWI      forest
# count  243.000000  243.000000  243.000000  243.00000  243.000000  243.000000
# mean    14.718107   49.423045    4.788889   16.71358    7.052675    0.502058
# std     12.373759   47.671186    4.177597   14.21361    7.430195    0.501028
# min      0.700000    6.900000    0.000000    1.10000    0.000000    0.000000
# 25%      5.800000   12.350000    1.400000    6.05000    0.750000    0.000000
# 50%     11.300000   33.100000    3.500000   12.40000    4.700000    1.000000
# 75%     20.800000   69.100000    7.300000   22.65000   11.450000    1.000000
# max     65.900000  220.400000   19.000000   68.00000   31.100000    1.000000

# %%
#checking correlation between all feature so we can remove some unimportant featurefrom our data

df.corr()
# Out:
#              Temperature        RH        Ws     Rain       FFMC       DMC  \
# Temperature     1.000000 -0.660116 -0.282788 -0.332942  0.678513  0.480745
#  RH            -0.660116  1.000000  0.236212  0.223174 -0.645989 -0.405293
#  Ws            -0.282788  0.236212  1.000000  0.170001 -0.163998 -0.001901
# Rain           -0.332942  0.223174  0.170001  1.000000 -0.545604 -0.290077
# FFMC            0.678513 -0.645989 -0.163998 -0.545604  1.000000  0.601346
# DMC             0.480745 -0.405293 -0.001901 -0.290077  0.601346  1.000000
# DC              0.368326 -0.220161  0.075814 -0.297942  0.502868  0.875112
# ISI             0.606881 -0.691222  0.014637 -0.348682  0.739070  0.673484
# BUI             0.453149 -0.348626  0.029181 -0.300622  0.588614  0.982023
# FWI             0.561384 -0.575731  0.030559 -0.325531  0.688348  0.875437
# forest         -0.286362  0.407851  0.176464  0.040013 -0.228452 -0.195433
#
#                    DC       ISI       BUI       FWI    forest
# Temperature  0.368326  0.606881  0.453149  0.561384 -0.286362
#  RH         -0.220161 -0.691222 -0.348626 -0.575731  0.407851
#  Ws          0.075814  0.014637  0.029181  0.030559  0.176464
# Rain        -0.297942 -0.348682 -0.300622 -0.325531  0.040013
# FFMC         0.502868  0.739070  0.588614  0.688348 -0.228452
# DMC          0.875112  0.673484  0.982023  0.875437 -0.195433
# DC           1.000000  0.497714  0.941808  0.738905  0.078890
# ISI          0.497714  1.000000  0.634813  0.913495 -0.272925
# BUI          0.941808  0.634813  1.000000  0.857597 -0.091133
# FWI          0.738905  0.913495  0.857597  1.000000 -0.199718
# forest       0.078890 -0.272925 -0.091133 -0.199718  1.000000

# %%
#we can also check with graph if any relationship occured between these features
sns.pairplot(df)

# %%
#we can also check with heatmap
sns.set(rc={'figure.figsize':(15,10)})
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#five  feature are highly correlated with FWI are 'FFMC' , 'DMC' , 'DC' , 'ISI' , 'BUI'
#so we can remove some feature from it.

# %%
#checking linearty and regression line of data

# %%
sns.set(rc={'figure.figsize':(8,6)})
sns.regplot(x="DMC",y="FWI",data=df)
# Out:
# <AxesSubplot:xlabel='DMC', ylabel='FWI'>

# %%
sns.set(rc={'figure.figsize':(8,6)})
sns.regplot(x="ISI",y="FWI",data=df)
# Out:
# <AxesSubplot:xlabel='ISI', ylabel='FWI'>

# %%
sns.set(rc={'figure.figsize':(8,6)})
sns.regplot(x="BUI",y="FWI",data=df)
# Out:
# <AxesSubplot:xlabel='BUI', ylabel='FWI'>

# %%
#checking outliers if any with boxplot

# %%
sns.boxplot(df['FWI'])
# Out:
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='FWI'>

# %%
sns.boxplot(df['ISI'])
# Out:
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ISI'>

# %%
df.head()
# Out:
#    Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI  BUI  FWI  forest
# 0           29   57   18    0.0  65.7  3.4   7.6  1.3  3.4  0.5       1
# 1           29   61   13    1.3  64.4  4.1   7.6  1.0  3.9  0.4       1
# 2           26   82   22   13.1  47.1  2.5   7.1  0.3  2.7  0.1       1
# 3           25   89   13    2.5  28.6  1.3   6.9  0.0  1.7  0.0       1
# 4           27   77   16    0.0  64.8  3.0  14.2  1.2  3.9  0.5       1

# %%
#now we have to select some important feature so we can train oure model

# %%
x = df.iloc[:,[0,1,2,3,6,7]] #independent features 
y = df.iloc[:,9]   #dependent features (FWI)

# %%
from sklearn.model_selection import train_test_split

# %%
# we are spliting our data into train data and test data so we can check our model accuracy

# %%
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.33, random_state=10)

# %%
#sns.displot(X_train,kind='kde')

# %%
## standardize the datasets
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
#sns.displot(X_train,kind='kde')

# %%
X_test = scaler.transform(X_test)

# %%
#now we are ready to train our data

# %%
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#print the coeff and intercept
print(regression.coef_)
print(regression.intercept_)
# Out:
# [-0.25029108  0.30630538 -0.28789957  0.43909581  2.75069331  6.02545086]
# 6.832716049382719

# %%
# prediction for test data
reg_pred= regression.predict(X_test)

# %%
reg_pred
# Out:
# array([ 4.2269314 ,  4.48951577, 10.3008625 , -0.20735821, -0.80178559,
#         7.71628594,  2.72919082, 10.93492573,  6.37133074,  0.21678211,
#         0.14586752,  7.53424493, 20.62506342, 12.22060511,  9.60901155,
#        14.48596086, -0.85589108, 17.41723002,  6.3110285 ,  2.81694727,
#         5.84259716, 27.07488494, 15.02459171,  2.7161335 ,  1.14583331,
#         8.90783449,  2.03544351,  1.44028011,  0.15987857, 14.47358591,
#         8.1771219 ,  5.42090988,  2.15450711,  9.20536236, 14.7434898 ,
#         0.4929451 ,  1.07079904, -0.11732388, 16.45518534,  0.08437794,
#        11.83342909, 10.35139151, 11.50722343, 14.06675627,  9.95608008,
#        23.55471694,  0.4701367 , 15.68585515, -1.66907608,  3.30507091,
#         6.60313147, 14.27893396,  3.1918148 ,  9.09588683, -1.09289943,
#        21.01484431, 10.8359908 ,  6.56713729,  0.57290644,  4.78594143,
#        12.81798736, -0.24932039,  1.40611934, 16.52640178, 25.13262911,
#         0.78992509,  3.61012733,  0.38273248, 15.68408123, -0.54241125,
#         6.92087072,  7.84936765,  0.55585965, -0.27531331, 20.99160665,
#         6.57417674,  3.22966516, -2.38769   , 26.09522231, -0.54425552,
#        16.85734282])

# %% [markdown]
# #now talk about assumption of linear regression

# %%
#first assumption
#plt.scatter(reg_pred,y_test)
#plt.xlabel('truth_test_value')
#plt.ylabel('predicted_FWI')

# %%
#this plot should be follow some linearity
sns.regplot(reg_pred,y_test)
# Out:
# C:\Users\bhupe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='FWI'>

# %%
## residuals
residuals = y_test-reg_pred

# %%
residuals
# Out:
# 46    -0.626931
# 227   -0.589516
# 182    0.599137
# 116    0.307358
# 126    0.901786
#          ...
# 129   -0.129665
# 243    2.587690
# 209    5.004778
# 102    0.844256
# 78    -0.757343
# Name: FWI, Length: 81, dtype: float64

# %%
sns.displot(residuals,kind="kde")

# %%
#sns.displot(reg_pred,kind='kde')

# %%
#scatter plot with prediction and residuals
# it should follow some unifrom distribution
plt.scatter(reg_pred,residuals)

# %%
# performance matrics
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test,reg_pred))
print(mean_absolute_error(y_test,reg_pred))
print(np.sqrt(mean_squared_error(y_test,reg_pred)))
# Out:
# 4.706804103340437
# 1.2319900879183392
# 2.169517020753798

# %%
# now checing r square and adjusted r square value for model accuracy

# %%
#r square
from sklearn.metrics import r2_score
score = r2_score(y_test,reg_pred)
print(score)
# Out:
# 0.9154082777895111

# %%
# adjusted r square
1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.9085494895021742

# %%
## Ridge regression
from sklearn.linear_model import Ridge
ridge=Ridge()

# %%
ridge.fit(X_train,y_train)
# Out:
# Ridge()

# %%
ridge_pred = ridge.predict(X_test)

# %%
ridge_pred
# Out:
# array([ 4.21002660e+00,  4.46261591e+00,  1.02742412e+01, -2.21493928e-01,
#        -8.12629468e-01,  7.69403501e+00,  2.82521350e+00,  1.09151836e+01,
#         6.35103628e+00,  3.22637911e-01,  1.95194770e-01,  7.50386569e+00,
#         2.05775156e+01,  1.21646227e+01,  9.70785845e+00,  1.44599013e+01,
#        -8.62838531e-01,  1.73438669e+01,  6.30643226e+00,  2.67766519e+00,
#         5.94766456e+00,  2.68444060e+01,  1.50165168e+01,  2.80264539e+00,
#         1.20226669e+00,  8.89095431e+00,  2.07405247e+00,  1.50567422e+00,
#         2.33745305e-01,  1.44466644e+01,  8.15595187e+00,  5.43202586e+00,
#         2.26036438e+00,  9.17455621e+00,  1.47579531e+01,  5.14294947e-01,
#         1.15054199e+00, -2.57175296e-02,  1.64330587e+01,  2.25236642e-01,
#         1.18112619e+01,  1.03304537e+01,  1.14829322e+01,  1.40792590e+01,
#         9.95750336e+00,  2.34397901e+01,  5.42909880e-01,  1.56550963e+01,
#        -1.65262504e+00,  3.27947601e+00,  6.57289955e+00,  1.42450682e+01,
#         3.19909660e+00,  9.05811884e+00, -1.10891013e+00,  2.09668723e+01,
#         1.08115379e+01,  6.61021227e+00,  5.33969653e-01,  4.83047135e+00,
#         1.27675947e+01, -2.09685137e-01,  1.31011777e+00,  1.64664157e+01,
#         2.50525498e+01,  7.44947302e-01,  3.70331986e+00,  3.99852556e-01,
#         1.56688213e+01, -4.70644258e-01,  6.85687914e+00,  7.78103769e+00,
#         6.37812616e-01, -2.35304720e-01,  2.09354106e+01,  6.52990158e+00,
#         3.27738907e+00, -2.27468967e+00,  2.60006978e+01, -4.87272296e-01,
#         1.68299078e+01])

# %%
#plt.scatter(y_test,ridge_pred)

# %%
sns.regplot(x=y_test,y=ridge_pred)
# Out:
# <AxesSubplot:xlabel='FWI'>

# %%
#r square
from sklearn.metrics import r2_score
score = r2_score(y_test,ridge_pred)
print(score)
# Out:
# 0.9167729910966741

# %%
# adjusted r square
1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.9100248552396477

# %%
# lasso regression

# %%
from sklearn.linear_model import Lasso

# %%
lasso = Lasso()

# %%
lasso
# Out:
# Lasso()

# %%
lasso.fit(X_train,y_train)
# Out:
# Lasso()

# %%
lasso.intercept_
# Out:
# 6.832716049382719

# %%
lasso.coef_
# Out:
# array([ 0.        , -0.        ,  0.        , -0.        ,  2.01265804,
#         4.82704512])

# %%
lasso_pred = lasso.predict(X_test)

# %%
#it shoul follo some linear relation
plt.scatter(y_test,lasso_pred)

# %%
#residuals
residuals = y_test-lasso_pred

# %%
sns.displot(residuals,kind="kde")

# %%
#lasso prediction and residuals value should follow uniform relation
plt.scatter(lasso_pred,residuals)

# %%
# performance matrics
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test,lasso_pred))
print(mean_absolute_error(y_test,lasso_pred))
print(np.sqrt(mean_squared_error(y_test,lasso_pred)))
# Out:
# 5.630459205783887
# 1.4455167609160273
# 2.3728588676497147

# %%
#r square
from sklearn.metrics import r2_score
score = r2_score(y_test,lasso_pred)
print(score)
# Out:
# 0.8988081444232753

# %%
# adjusted r square
1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.8906033993765138

# %%
#elasticnet

# %%
from sklearn.linear_model import ElasticNet

# %%
elastic = ElasticNet()

# %%
elastic.fit(X_train,y_train)
# Out:
# ElasticNet()

# %%
elastic.coef_
# Out:
# array([ 0.35073405, -0.56098865,  0.        , -0.00391566,  2.06850702,
#         3.14071565])

# %%
elastic.intercept_
# Out:
# 6.832716049382719

# %%
elastic_pred=elastic.predict(X_test)

# %%
#assumption

# %%
plt.scatter(y_test,elastic_pred) #it should follw some linearity

# %%
#residuals
residuals=y_test-elastic_pred

# %%
sns.displot(residuals,kind='kde') # mostly uniform with some right skewness

# %%
plt.scatter(elastic_pred,residuals) #it should folllw some uniform distribution

# %%
# performance matrics
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test,elastic_pred))
print(mean_absolute_error(y_test,elastic_pred))
print(np.sqrt(mean_squared_error(y_test,elastic_pred)))
# Out:
# 8.436716754658912
# 2.118876634566146
# 2.90460268447492

# %%
#r square
from sklearn.metrics import r2_score
score = r2_score(y_test,elastic_pred)
print(score)
# Out:
# 0.8483734643699776

# %%
# adjusted r square
1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.8360794209405163

# %% [markdown]
# # conclusion

# %% [markdown]
# 1) Here we have perform EDA and feature scalling on algerian forest fire dataset so we can create a model or predict FWI values on the basis of some independent feature.
#
# 2) so we have notice that 'FFMC' , 'DMC' , 'DC' , 'ISI' , 'BUI' these feature are highly correlated with so we remove some features.
#
# 3) so we use these six feature as independet feature.
#
# 4) after this we split our data into train and test data.
#
# 5) we perform regression on train data.
#
# 6) after model training we check our model accuracy with dependent feature of test data with prediction values of model.
#
# 7) our model accuracy is approx 84 percent so we can say that our model is trained well.
